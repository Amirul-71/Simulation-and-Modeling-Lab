# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Generate 10 random numbers in [0,1)
random_numbers = np.random.rand(10)

# Plot the histogram
plt.hist(random_numbers, bins=20,  alpha=0.5, color='blue', edgecolor='black')

# Labels and title
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Histogram of Uniformly Distributed Random Numbers')
plt.grid(                                                                                                                                                                                                                                                              )

# Show the plot
plt.show()

# %%
# Generate 500 random values from a normal distribution
SNormalValues = np.random.randn(500)
#mean=0, standard deviation=1

# Create a histogram
plt.hist(SNormalValues, bins=10, edgecolor='black')
plt.title('Histogram of Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
# With Seed
np.random.seed(10)  # Setting seed to 10
seeded_matrix = np.random.randint(1, 51, (3, 3))
print("Seeded Random Matrix:\n", seeded_matrix)

# Without Seed
np.random.seed(None)  # No seed, generates different values each time
non_seeded_matrix = np.random.randint(1, 50, (3, 3))
print("\nNon-Seeded Random Matrix:\n", non_seeded_matrix)
# Out:
# Seeded Random Matrix:
#  [[10 37 16]
#  [ 1 50 29]
#  [26 30 49]]
#
# Non-Seeded Random Matrix:
#  [[25 37  7]
#  [ 1 20 23]
#  [27 41 38]]

# %%
import random  # to create random numbers

def estimate_pi(num_points):
    inside = 0  # how many points inside the circle

    for _ in range(num_points):
        x = random.randint(0,7)  # pick a random number from 0 to 7
        y = random.randint(0,7)
        print(x,y)
        if x*x + y*y <= 49:
            inside += 1  # it's inside the circle

    pi = 4 * inside / num_points
    print("Estimated pi for", num_points, "points is:", pi)


# Try this with different number of points
estimate_pi(5)
# Out:
# 0 7
# 6 1
# 3 2
# 4 3
# 6 0
# Estimated pi for 5 points is: 4.0
